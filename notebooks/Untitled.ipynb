# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/sample/meta_Computers.json.gz
# Out:
# --2022-05-23 17:30:07--  http://deepyeti.ucsd.edu/jianmo/amazon/sample/meta_Computers.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7010521 (6.7M) [application/octet-stream]
# Saving to: ‘meta_Computers.json.gz.1’
#
# meta_Computers.json 100%[===================>]   6.69M  1.67MB/s    in 5.9s
#
# 2022-05-23 17:30:13 (1.14 MB/s) - ‘meta_Computers.json.gz.1’ saved [7010521/7010521]

# %%
### load the meta data

data = []
with gzip.open('meta_Computers.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(data))

# first row of the list
print(data[0])
# Out:
# 18772
# {'description': ['Brand new. Still in factory-sealed plastic.'], 'title': 'Kelby Training DVD: The Adobe Photoshop CS5 7-Point System for Camera Raw By Scott Kelby', 'image': ['https://images-na.ssl-images-amazon.com/images/I/31IlLImCVJL._SS40_.jpg'], 'brand': 'Kelby Training', 'rank': ['>#654,681 in Electronics (See Top 100 in Electronics)'], 'main_cat': 'Computers', 'date': 'December 2, 2011', 'asin': '0321732960'}

# %%
# convert list into pandas dataframe

df = pd.DataFrame.from_dict(data)

print(len(df))
# Out:
# 18772

# %%
### remove rows with unformatted title (i.e. some 'title' may still contain html style content)

df3 = df.fillna('')
df4 = df3[df3.title.str.contains('getTime')] # unformatted rows
df5 = df3[~df3.title.str.contains('getTime')] # filter those unformatted rows
print(len(df4))
print(len(df5))
# Out:
# 135
# 18637

# %%
# how those unformatted rows look like
df4.iloc[0]
# Out:
# description
# title           var aPageStart = (new Date()).getTime();\nvar ...
# image
# brand                                              DS Miller Inc.
# rank            [>#1,826,312 in Electronics (See Top 100 in El...
# main_cat                                                Computers
# date                                                March 1, 2010
# asin                                                   B0016C5EXY
# feature
# tech1
# also_buy
# price
# also_view
# tech2
# details
# similar_item
# Name: 1186, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18772 entries, 0 to 18771
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   5130 non-null   object
#  1   title         18771 non-null  object
#  2   image         14084 non-null  object
#  3   brand         18295 non-null  object
#  4   rank          18080 non-null  object
#  5   main_cat      18772 non-null  object
#  6   date          18588 non-null  object
#  7   asin          18772 non-null  object
#  8   feature       4107 non-null   object
#  9   tech1         3586 non-null   object
#  10  also_buy      1435 non-null   object
#  11  price         2650 non-null   object
#  12  also_view     2300 non-null   object
#  13  tech2         1659 non-null   object
#  14  details       26 non-null     object
#  15  similar_item  363 non-null    object
# dtypes: object(16)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#                                          description  \
# 0      [Brand new. Still in factory-sealed plastic.]
# 1  [If you're already a Photoshop user and want a...
# 2  [School To Home Notes: Note From the Teacher!\...
# 3  [Dooqi is a young brand specializing in high-e...
# 4                                [Cover for Nook HD]
#
#                                                title  \
# 0  Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1  Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2  TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3  [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                            Hd+ Cheetah Cover- Nook
#
#                                                image            brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1  [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2  [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3  [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                NaN             Nook
#
#                                                 rank   main_cat  \
# 0  [>#654,681 in Electronics (See Top 100 in Elec...  Computers
# 1  [>#830,165 in Electronics (See Top 100 in Elec...  Computers
# 2  [>#1,233,887 in Electronics (See Top 100 in El...  Computers
# 3  [>#454,595 in Electronics (See Top 100 in Elec...  Computers
# 4  [>#85,661 in Computers & Accessories (See top ...  Computers
#
#                  date        asin  \
# 0    December 2, 2011  0321732960
# 1    November 7, 2011  0321735722
# 2        June 6, 2007  0439651859
# 3    December 5, 2014  0545729971
# 4  September 11, 2013  0594450284
#
#                                              feature  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [Hard coated for Scratch Proof (Hardness: 4H),...
# 4                                    [Cheetah cover]
#
#                                                tech1 also_buy price also_view  \
# 0                                                NaN      NaN   NaN       NaN
# 1                                                NaN      NaN   NaN       NaN
# 2                                                NaN      NaN   NaN       NaN
# 3                                                NaN      NaN   NaN       NaN
# 4  {'Brand Name': 'Nook', 'Item Weight': '1 pound...      NaN   NaN       NaN
#
#   tech2 details similar_item
# 0   NaN     NaN          NaN
# 1   NaN     NaN          NaN
# 2   NaN     NaN          NaN
# 3   NaN     NaN          NaN
# 4   NaN     NaN          NaN

# %%
df5.description=df5.description.map(lambda x: str(x))
# Out:
# /Users/nayoungkim/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df5.columns
# Out:
# Index(['description', 'title', 'image', 'brand', 'rank', 'main_cat', 'date',
#        'asin', 'feature', 'tech1', 'also_buy', 'price', 'also_view', 'tech2',
#        'details', 'similar_item'],
#       dtype='object')

# %%
df5.description=df5.description.str.strip("[]'")
df5[df5.description=="Brand new. Still in factory-sealed plastic."]
# Out:
#                                    description  \
# 0  Brand new. Still in factory-sealed plastic.
#
#                                                title  \
# 0  Kelby Training DVD: The Adobe Photoshop CS5 7-...
#
#                                                image           brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...  Kelby Training
#
#                                                 rank   main_cat  \
# 0  [>#654,681 in Electronics (See Top 100 in Elec...  Computers
#
#                date        asin feature tech1 also_buy price also_view tech2  \
# 0  December 2, 2011  0321732960
#
#   details similar_item
# 0

# %%
df5.drop(columns=['feature', 'tech1', 'also_buy', 'price', 'also_view', 'tech2','details', 'similar_item'],inplace=True)
# Out:
# /Users/nayoungkim/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df5["brand"].groupby(df5["brand"].isna()).count()
# Out:
# brand
# False    18637
# Name: brand, dtype: int64

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18637 entries, 0 to 18771
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  18637 non-null  object
#  1   title        18637 non-null  object
#  2   image        18637 non-null  object
#  3   brand        18637 non-null  object
#  4   rank         18637 non-null  object
#  5   main_cat     18637 non-null  object
#  6   date         18637 non-null  object
#  7   asin         18637 non-null  object
# dtypes: object(8)
# memory usage: 1.8+ MB

# %%
df5['brand_cat']=df5.brand.map(lambda x : 0 if len(x) <1 else 1)
df5.brand_cat.unique()
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2771495910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['brand_cat']=df5.brand.map(lambda x : 0 if len(x) <1 else 1)
# array([1, 0])

# %%
df5.drop(columns="main_cat")
# Out:
#                                              description  \
# 0        ['Brand new. Still in factory-sealed plastic.']
# 1      ["If you're already a Photoshop user and want ...
# 2      ['School To Home Notes: Note From the Teacher!...
# 3      ["Dooqi is a young brand specializing in high-...
# 4                                  ['Cover for Nook HD']
# ...                                                  ...
# 18767
# 18768
# 18769  ['Deadpool is a mercenary and anti-hero appear...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#                                                     rank                date  \
# 0      [>#654,681 in Electronics (See Top 100 in Elec...    December 2, 2011
# 1      [>#830,165 in Electronics (See Top 100 in Elec...    November 7, 2011
# 2      [>#1,233,887 in Electronics (See Top 100 in El...        June 6, 2007
# 3      [>#454,595 in Electronics (See Top 100 in Elec...    December 5, 2014
# 4      [>#85,661 in Computers & Accessories (See top ...  September 11, 2013
# ...                                                  ...                 ...
# 18767  [>#372,769 in Electronics (See Top 100 in Elec...       July 11, 2016
# 18768  [>#308,759 in Electronics (See Top 100 in Elec...       June 29, 2016
# 18769  [>#4,064 in Computers & Accessories (See top 1...       June 24, 2016
# 18770  [>#449,492 in Electronics (See Top 100 in Elec...       March 5, 2017
# 18771  [>#278,362 in Electronics (See Top 100 in Elec...      March 16, 2017
#
#              asin  brand_cat
# 0      0321732960          1
# 1      0321735722          1
# 2      0439651859          1
# 3      0545729971          1
# 4      0594450284          1
# ...           ...        ...
# 18767  B01HI72XZW          0
# 18768  B01HIEI83Q          0
# 18769  B01HIQYNJM          1
# 18770  B01HIWBL46          1
# 18771  B01HJ49FSW          1
#
# [18637 rows x 8 columns]

# %%
df5
# Out:
#                                              description  \
# 0            Brand new. Still in factory-sealed plastic.
# 1      "If you're already a Photoshop user and want a...
# 2      School To Home Notes: Note From the Teacher!\\...
# 3      "Dooqi is a young brand specializing in high-e...
# 4                                      Cover for Nook HD
# ...                                                  ...
# 18767
# 18768
# 18769  Deadpool is a mercenary and anti-hero appearin...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#       rank   main_cat                date        asin  brand_cat rank1
# 0      nan  Computers    December 2, 2011  0321732960          1   nan
# 1      nan  Computers    November 7, 2011  0321735722          1   nan
# 2      nan  Computers        June 6, 2007  0439651859          1   nan
# 3      nan  Computers    December 5, 2014  0545729971          1   nan
# 4      nan  Computers  September 11, 2013  0594450284          1   nan
# ...    ...        ...                 ...         ...        ...   ...
# 18767  nan  Computers       July 11, 2016  B01HI72XZW          0   nan
# 18768  nan  Computers       June 29, 2016  B01HIEI83Q          0   nan
# 18769  nan  Computers       June 24, 2016  B01HIQYNJM          1   nan
# 18770  nan  Computers       March 5, 2017  B01HIWBL46          1   nan
# 18771  nan  Computers      March 16, 2017  B01HJ49FSW          1   nan
#
# [18637 rows x 10 columns]

# %%
df5['rank1']=df5['rank'].map(lambda x: str(x).strip("[]'"))
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2613211194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['rank1']=df5['rank'].map(lambda x: str(x).strip("[]'"))

# %%
df5
# Out:
#                                              description  \
# 0        ['Brand new. Still in factory-sealed plastic.']
# 1      ["If you're already a Photoshop user and want ...
# 2      ['School To Home Notes: Note From the Teacher!...
# 3      ["Dooqi is a young brand specializing in high-...
# 4                                  ['Cover for Nook HD']
# ...                                                  ...
# 18767
# 18768
# 18769  ['Deadpool is a mercenary and anti-hero appear...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#                                                     rank   main_cat  \
# 0      [>#654,681 in Electronics (See Top 100 in Elec...  Computers
# 1      [>#830,165 in Electronics (See Top 100 in Elec...  Computers
# 2      [>#1,233,887 in Electronics (See Top 100 in El...  Computers
# 3      [>#454,595 in Electronics (See Top 100 in Elec...  Computers
# 4      [>#85,661 in Computers & Accessories (See top ...  Computers
# ...                                                  ...        ...
# 18767  [>#372,769 in Electronics (See Top 100 in Elec...  Computers
# 18768  [>#308,759 in Electronics (See Top 100 in Elec...  Computers
# 18769  [>#4,064 in Computers & Accessories (See top 1...  Computers
# 18770  [>#449,492 in Electronics (See Top 100 in Elec...  Computers
# 18771  [>#278,362 in Electronics (See Top 100 in Elec...  Computers
#
#                      date        asin  brand_cat  \
# 0        December 2, 2011  0321732960          1
# 1        November 7, 2011  0321735722          1
# 2            June 6, 2007  0439651859          1
# 3        December 5, 2014  0545729971          1
# 4      September 11, 2013  0594450284          1
# ...                   ...         ...        ...
# 18767       July 11, 2016  B01HI72XZW          0
# 18768       June 29, 2016  B01HIEI83Q          0
# 18769       June 24, 2016  B01HIQYNJM          1
# 18770       March 5, 2017  B01HIWBL46          1
# 18771      March 16, 2017  B01HJ49FSW          1
#
#                                                    rank1
# 0      >#654,681 in Electronics (See Top 100 in Elect...
# 1      >#830,165 in Electronics (See Top 100 in Elect...
# 2      >#1,233,887 in Electronics (See Top 100 in Ele...
# 3      >#454,595 in Electronics (See Top 100 in Elect...
# 4      >#85,661 in Computers & Accessories (See top 100)
# ...                                                  ...
# 18767  >#372,769 in Electronics (See Top 100 in Elect...
# 18768  >#308,759 in Electronics (See Top 100 in Elect...
# 18769   >#4,064 in Computers & Accessories (See top 100)
# 18770  >#449,492 in Electronics (See Top 100 in Elect...
# 18771  >#278,362 in Electronics (See Top 100 in Elect...
#
# [18637 rows x 10 columns]

# %%
df5["rank1"]=df5["rank1"].map(lambda x: str(x))
df5["rank1"]=df5["rank1"].str.replace(pat='>#',repl='', regex=False)
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/4145307409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["rank1"]=df5["rank1"].map(lambda x: str(x))
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/4145307409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["rank1"]=df5["rank1"].str.replace(pat='>#',repl='', regex=False)

# %%
df5["rank1"]=df5["rank1"].map(lambda x: x.replace(",",""))
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2162198519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["rank1"]=df5["rank1"].map(lambda x: x.replace(",",""))

# %%
df5["rank1"].head
# Out:
# <bound method NDFrame.head of 0        654681 in Electronics (See Top 100 in Electron...
# 1        830165 in Electronics (See Top 100 in Electron...
# 2        1233887 in Electronics (See Top 100 in Electro...
# 3        454595 in Electronics (See Top 100 in Electron...
# 4           85661 in Computers & Accessories (See top 100)
#                                ...
# 18767    372769 in Electronics (See Top 100 in Electron...
# 18768    308759 in Electronics (See Top 100 in Electron...
# 18769        4064 in Computers & Accessories (See top 100)
# 18770    449492 in Electronics (See Top 100 in Electron...
# 18771    278362 in Electronics (See Top 100 in Electron...
# Name: rank1, Length: 18637, dtype: object>

# %%
df5["rank1"]=df5["rank1"].map(lambda x: x.split("in"))
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/743146037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["rank1"]=df5["rank1"].map(lambda x: x.split("in"))

# %%
df5["rank1"] = df5["rank1"].map(lambda x: x[0])
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/1942946291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["rank1"] = df5["rank1"].map(lambda x: x[0])

# %%
df5
# Out:
#                                              description  \
# 0        ['Brand new. Still in factory-sealed plastic.']
# 1      ["If you're already a Photoshop user and want ...
# 2      ['School To Home Notes: Note From the Teacher!...
# 3      ["Dooqi is a young brand specializing in high-...
# 4                                  ['Cover for Nook HD']
# ...                                                  ...
# 18767
# 18768
# 18769  ['Deadpool is a mercenary and anti-hero appear...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#                                                     rank   main_cat  \
# 0      [>#654,681 in Electronics (See Top 100 in Elec...  Computers
# 1      [>#830,165 in Electronics (See Top 100 in Elec...  Computers
# 2      [>#1,233,887 in Electronics (See Top 100 in El...  Computers
# 3      [>#454,595 in Electronics (See Top 100 in Elec...  Computers
# 4      [>#85,661 in Computers & Accessories (See top ...  Computers
# ...                                                  ...        ...
# 18767  [>#372,769 in Electronics (See Top 100 in Elec...  Computers
# 18768  [>#308,759 in Electronics (See Top 100 in Elec...  Computers
# 18769  [>#4,064 in Computers & Accessories (See top 1...  Computers
# 18770  [>#449,492 in Electronics (See Top 100 in Elec...  Computers
# 18771  [>#278,362 in Electronics (See Top 100 in Elec...  Computers
#
#                      date        asin  brand_cat     rank1
# 0        December 2, 2011  0321732960          1   654681
# 1        November 7, 2011  0321735722          1   830165
# 2            June 6, 2007  0439651859          1  1233887
# 3        December 5, 2014  0545729971          1   454595
# 4      September 11, 2013  0594450284          1    85661
# ...                   ...         ...        ...       ...
# 18767       July 11, 2016  B01HI72XZW          0   372769
# 18768       June 29, 2016  B01HIEI83Q          0   308759
# 18769       June 24, 2016  B01HIQYNJM          1     4064
# 18770       March 5, 2017  B01HIWBL46          1   449492
# 18771      March 16, 2017  B01HJ49FSW          1   278362
#
# [18637 rows x 10 columns]

# %%
df6=df5[df5["rank1"]!='']

# %%
df6["rank1"]=df6["rank1"].astype("int64")
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2319163233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6["rank1"]=df6["rank1"].astype("int64")

# %%
df6
# Out:
#                                              description  \
# 0        ['Brand new. Still in factory-sealed plastic.']
# 1      ["If you're already a Photoshop user and want ...
# 2      ['School To Home Notes: Note From the Teacher!...
# 3      ["Dooqi is a young brand specializing in high-...
# 4                                  ['Cover for Nook HD']
# ...                                                  ...
# 18767
# 18768
# 18769  ['Deadpool is a mercenary and anti-hero appear...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#                                                     rank   main_cat  \
# 0      [>#654,681 in Electronics (See Top 100 in Elec...  Computers
# 1      [>#830,165 in Electronics (See Top 100 in Elec...  Computers
# 2      [>#1,233,887 in Electronics (See Top 100 in El...  Computers
# 3      [>#454,595 in Electronics (See Top 100 in Elec...  Computers
# 4      [>#85,661 in Computers & Accessories (See top ...  Computers
# ...                                                  ...        ...
# 18767  [>#372,769 in Electronics (See Top 100 in Elec...  Computers
# 18768  [>#308,759 in Electronics (See Top 100 in Elec...  Computers
# 18769  [>#4,064 in Computers & Accessories (See top 1...  Computers
# 18770  [>#449,492 in Electronics (See Top 100 in Elec...  Computers
# 18771  [>#278,362 in Electronics (See Top 100 in Elec...  Computers
#
#                      date        asin  brand_cat    rank1
# 0        December 2, 2011  0321732960          1   654681
# 1        November 7, 2011  0321735722          1   830165
# 2            June 6, 2007  0439651859          1  1233887
# 3        December 5, 2014  0545729971          1   454595
# 4      September 11, 2013  0594450284          1    85661
# ...                   ...         ...        ...      ...
# 18767       July 11, 2016  B01HI72XZW          0   372769
# 18768       June 29, 2016  B01HIEI83Q          0   308759
# 18769       June 24, 2016  B01HIQYNJM          1     4064
# 18770       March 5, 2017  B01HIWBL46          1   449492
# 18771      March 16, 2017  B01HJ49FSW          1   278362
#
# [17952 rows x 10 columns]

# %%
df6.sort_values("rank1")
# Out:
#                                              description  \
# 13181  ['Nothing says "Game Over" for the Xbox One ex...
# 18609  ["This Bundle is only designed for Apple Penci...
# 17337  ['Logitech Wireless Touch Keyboard K400 Plus L...
# 5859   ['Micro USB Host OTG Cable with Micro USB Powe...
# 14412  ['SHD(Super High-Definition )Pursuit of High D...
# ...                                                  ...
# 15219  ['There are two Network Display amplifiers: th...
# 15559
# 5136   ['Protect Computer Products Ch1110-104 Cherry ...
# 15494
# 7670   ['City Threads 3-Pocket Shorts (Baby) - Charco...
#
#                                                    title  \
# 13181  Seagate Game Drive for Xbox 2TB Green (STEA200...
# 18609  [3-Piece] Fintie Bundle for Apple Pencil Cap H...
# 17337  Logitech Wireless Touch Keyboard K400 Plus wit...
# 5859   DSYJ Micro USB Host OTG Cable with Micro USB P...
# 14412  RJ45 Connectors,SHD Cat6 Connector Cat5e Conne...
# ...                                                  ...
# 15219  Crown DCi 8|600ND | 8 Channel AVB Power Amplif...
# 15559  Sling Handle Grip Long Shaped With Strap - Uni...
# 5136   Protect Computer Products Cherry Kb-0556/ku-05...
# 15494  Liili Mouse Pad Natural Rubber Mousepad Basket...
# 7670   City Threads 3-Pocket Shorts (Baby) - Charcoal...
#
#                                                    image  \
# 13181  [https://images-na.ssl-images-amazon.com/image...
# 18609  [https://images-na.ssl-images-amazon.com/image...
# 17337  [https://images-na.ssl-images-amazon.com/image...
# 5859
# 14412  [https://images-na.ssl-images-amazon.com/image...
# ...                                                  ...
# 15219  [https://images-na.ssl-images-amazon.com/image...
# 15559  [https://images-na.ssl-images-amazon.com/image...
# 5136
# 15494  [https://images-na.ssl-images-amazon.com/image...
# 7670   [https://images-na.ssl-images-amazon.com/image...
#
#                            brand  \
# 13181                    Seagate
# 18609                     Fintie
# 17337                   Logitech
# 5859                        DSYJ
# 14412                        SHD
# ...                          ...
# 15219                      Crown
# 15559                 SaiTech IT
# 5136   PROTECT COMPUTER PRODUCTS
# 15494                  Liili Inc
# 7670                City Threads
#
#                                                     rank   main_cat  \
# 13181    [>#54 in Computers & Accessories (See top 100)]  Computers
# 18609  [>#259 in Electronics (See Top 100 in Electron...  Computers
# 17337   [>#307 in Computers & Accessories (See top 100)]  Computers
# 5859    [>#333 in Computers & Accessories (See top 100)]  Computers
# 14412  [>#367 in Electronics (See Top 100 in Electron...  Computers
# ...                                                  ...        ...
# 15219  [>#2,009,707 in Electronics (See Top 100 in El...  Computers
# 15559  [>#2,009,897 in Electronics (See Top 100 in El...  Computers
# 5136   [>#2,010,923 in Electronics (See Top 100 in El...  Computers
# 15494  [>#2,033,187 in Office Products (See Top 100 i...  Computers
# 7670   [>#9,464,714 in Home & Kitchen (See Top 100 in...  Computers
#
#                     date        asin  brand_cat    rank1
# 13181     August 5, 2015  B01065S79E          1       54
# 18609      June 17, 2016  B01H6Q03IY          1      259
# 17337      April 8, 2016  B01E0BUPW2          1      307
# 5859        May 21, 2013  B00CXAC1ZW          1      333
# 14412   November 9, 2017  B015OBFQNK          1      367
# ...                  ...         ...        ...      ...
# 15219      March 1, 2016  B017X020NO          1  2009707
# 15559      June 16, 2016  B0194WKAYA          1  2009897
# 5136   December 26, 2012  B00AT4O39Q          1  2010923
# 15494       May 19, 2016  B018WYMD2S          1  2033187
# 7670       July 23, 2014  B00IMO964C          1  9464714
#
# [17952 rows x 10 columns]

# %%
df5["title_count"] = df5["title"].map(lambda x: len(x))
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2895480165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["title_count"] = df5["title"].map(lambda x: len(x))

# %%
df5
# Out:
#                                              description  \
# 0        ['Brand new. Still in factory-sealed plastic.']
# 1      ["If you're already a Photoshop user and want ...
# 2      ['School To Home Notes: Note From the Teacher!...
# 3      ["Dooqi is a young brand specializing in high-...
# 4                                  ['Cover for Nook HD']
# ...                                                  ...
# 18767
# 18768
# 18769  ['Deadpool is a mercenary and anti-hero appear...
# 18770
# 18771
#
#                                                    title  \
# 0      Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1      Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2      TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3      [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                                Hd+ Cheetah Cover- Nook
# ...                                                  ...
# 18767  iPad Mini 4 Case, Aceguarder New Design [Dirtp...
# 18768  MIJIU Nylon Canvas Military Tactical Men Waist...
# 18769                    Marvel Deadpool Laptop Backpack
# 18770                            Funnel Cup (Ultra Pink)
# 18771  Linux Ubuntu 16.04 Desktop Server 32bit 64bit ...
#
#                                                    image            brand  \
# 0      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1      [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2      [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# 3      [https://images-na.ssl-images-amazon.com/image...            dooqi
# 4                                                                    Nook
# ...                                                  ...              ...
# 18767  [https://images-na.ssl-images-amazon.com/image...
# 18768  [https://images-na.ssl-images-amazon.com/image...
# 18769  [https://images-na.ssl-images-amazon.com/image...         Bioworld
# 18770  [https://images-na.ssl-images-amazon.com/image...             JDDZ
# 18771  [https://images-na.ssl-images-amazon.com/image...          Generic
#
#                                                     rank   main_cat  \
# 0      [>#654,681 in Electronics (See Top 100 in Elec...  Computers
# 1      [>#830,165 in Electronics (See Top 100 in Elec...  Computers
# 2      [>#1,233,887 in Electronics (See Top 100 in El...  Computers
# 3      [>#454,595 in Electronics (See Top 100 in Elec...  Computers
# 4      [>#85,661 in Computers & Accessories (See top ...  Computers
# ...                                                  ...        ...
# 18767  [>#372,769 in Electronics (See Top 100 in Elec...  Computers
# 18768  [>#308,759 in Electronics (See Top 100 in Elec...  Computers
# 18769  [>#4,064 in Computers & Accessories (See top 1...  Computers
# 18770  [>#449,492 in Electronics (See Top 100 in Elec...  Computers
# 18771  [>#278,362 in Electronics (See Top 100 in Elec...  Computers
#
#                      date        asin  brand_cat     rank1  title_count
# 0        December 2, 2011  0321732960          1   654681            88
# 1        November 7, 2011  0321735722          1   830165            72
# 2            June 6, 2007  0439651859          1  1233887            58
# 3        December 5, 2014  0545729971          1   454595           201
# 4      September 11, 2013  0594450284          1    85661            23
# ...                   ...         ...        ...       ...          ...
# 18767       July 11, 2016  B01HI72XZW          0   372769           187
# 18768       June 29, 2016  B01HIEI83Q          0   308759            55
# 18769       June 24, 2016  B01HIQYNJM          1     4064            31
# 18770       March 5, 2017  B01HIWBL46          1   449492            23
# 18771      March 16, 2017  B01HJ49FSW          1   278362           160
#
# [18637 rows x 11 columns]

# %%
df5["desc_count"] = df5["description"].map(lambda x: len(x))
df5["img_count"] = df5["image"].map(lambda x: len(x))
# Out:
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2157896181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["desc_count"] = df5["description"].map(lambda x: len(x))
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/2157896181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["img_count"] = df5["image"].map(lambda x: len(x))

# %%
df6=df5[df5["rank1"]!=""]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = df6[["brand_cat","title_count","desc_count","img_count"]]
# y = df6[["rank1"]].astype("int64")
y=df6.rank1
         
         
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)
X_train.shape,X_test.shape
# Out:
# ((12566, 4), (5386, 4))

# %%
y.info()
# y=df6.rank1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wt/rwb6pf811kx2_nd378hpt9680000gn/T/ipykernel_74007/3904923366.py in <module>
# ----> 1 y.info()
#       2 # y=df6.rank1
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
model = LinearRegression().fit(X_train, y_train)
model.
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'coef_': array([ 22786.03003739,   -379.73338187,   -220.19528687, -52077.40497758]),
#  '_residues': 2681625964155208.0,
#  'rank_': 4,
#  'singular_': array([3.91767251e+04, 8.06835776e+03, 2.57861676e+02, 1.75239792e+01]),
#  'intercept_': 796115.181054909}

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(y)
# Out:
# (array([1953., 1779., 1785., 1790., 1783., 1781., 1776., 1772., 1768.,
#         1765.]),
#  array([    0. ,  1763.8,  3527.6,  5291.4,  7055.2,  8819. , 10582.8,
#         12346.6, 14110.4, 15874.2, 17638. ]),
#  <BarContainer object of 10 artists>)
